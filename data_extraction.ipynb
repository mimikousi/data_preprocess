# %%
import pandas as pd

# %%
#表示する列数を増やす
pd.set_option('display.max_columns', 100)

#データを読み込みます
df = pd.read_csv('2020413.csv', index_col=0, header=0, encoding='shift-jis')

#読み込んだデータの先頭５行を表示
df.head()
# Out:
#                        気化器圧力_PV    気化器圧力_SV   気化器圧力_MV  気化器液面レベル_PV  \
# 2020-04-13 00:00:00  127.983294  127.883920  18.728267     0.700204
# 2020-04-13 00:00:01  128.262272  127.807691  18.728267     0.700865
# 2020-04-13 00:00:02  127.899077  127.991074  19.079324     0.699740
# 2020-04-13 00:00:03  127.622218  127.990697  18.772228     0.699970
# 2020-04-13 00:00:04  127.577243  127.903788  18.605173     0.700939
#
#                      気化器液面レベル_SV   気化器液面レベル_MV    気化器温度_PV  気化器ヒータ出口温度_PV  \
# 2020-04-13 00:00:00          0.7  21876.987772  120.159558     151.274003
# 2020-04-13 00:00:01          0.7  21876.987772  120.072575     151.218620
# 2020-04-13 00:00:02          0.7  21918.359526  120.305327     151.201067
# 2020-04-13 00:00:03          0.7  21892.166478  120.219488     151.220816
# 2020-04-13 00:00:04          0.7  21885.688813  120.302267     151.165624
#
#                      気化器ヒータ出口温度_SV  気化器ヒータ熱量_MV  反応器出口温度_PV  反応器出口温度_SV  \
# ...

# %%
df.columns
# Out:
# Index(['気化器圧力_PV', '気化器圧力_SV', '気化器圧力_MV', '気化器液面レベル_PV', '気化器液面レベル_SV',
#        '気化器液面レベル_MV', '気化器温度_PV', '気化器ヒータ出口温度_PV', '気化器ヒータ出口温度_SV',
#        '気化器ヒータ熱量_MV', '反応器出口温度_PV', '反応器出口温度_SV', '反応器外殻温度_MV',
#        '熱交換器入口流量（製品ガス）_PV', '熱交換器出口温度（リサイクルガス）_PV', '熱交換器出力温度（製品ガス）_PV',
#        '熱交換器出力温度（製品ガス）_SV', '熱交換器バルブ開度_MV', 'セパレータ液面レベル_PV', 'セパレータ液面レベル_SV',
#        'セパレータ液体排出量_MV', 'セパレータ液体温度_PV', 'セパレータ液体温度_SV', 'セパレータ外殻温度_MV',
#        'コンプレッサー出口温度_PV', 'コンプレッサー出口温度_SV', 'コンプレッサーヒーター熱量_MV', 'リサイクルガス圧力_PV',
#        'リサイクルガス圧力_SV', '原材料C2H4供給量_MV', 'アブソーバ液面レベル_PV', 'アブソーバ液面レベル_SV',
#        'アブソーバ液体排出量_MV', 'アブソーバ還流温度_PV', 'アブソーバ還流温度_SV', 'アブソーバ還流クーラー熱量_MV',
#        'アブソーバスクラブ温度_PV', 'アブソーバスクラブ温度_SV', 'アブソーバスクラブクーラー熱量_MV',
#        'リサイクルガス流量_PV', '有機生成物流量_MV', '有機生成物レベル_PV', '有機生成物レベル_SV',
#        '有機生成物流量_MV.1', '水溶液レベル_PV', '水溶液レベル_SV', '水溶液流量_MV', 'デカンタ温度_PV',
#        'デカンタ温度_SV', 'コンデンサ熱量_MV', '蒸留塔液面レベル_PV', '蒸留塔液面レベル_SV', '蒸留塔液体排出量_MV',
# ...

# %%
df['気化器圧力_PV']
# Out:
# 2020-04-13 00:00:00    127.983294
# 2020-04-13 00:00:01    128.262272
# 2020-04-13 00:00:02    127.899077
# 2020-04-13 00:00:03    127.622218
# 2020-04-13 00:00:04    127.577243
#                           ...
# 2020-04-13 23:59:56    128.403376
# 2020-04-13 23:59:57    128.588067
# 2020-04-13 23:59:58    127.902731
# 2020-04-13 23:59:59    127.481159
# 2020-04-14 00:00:00    127.047655
# Name: 気化器圧力_PV, Length: 86401, dtype: float64

# %%
df[['気化器圧力_PV', '気化器液面レベル_PV']]
# Out:
#                        気化器圧力_PV  気化器液面レベル_PV
# 2020-04-13 00:00:00  127.983294     0.700204
# 2020-04-13 00:00:01  128.262272     0.700865
# 2020-04-13 00:00:02  127.899077     0.699740
# 2020-04-13 00:00:03  127.622218     0.699970
# 2020-04-13 00:00:04  127.577243     0.700939
# ...                         ...          ...
# 2020-04-13 23:59:56  128.403376     0.699906
# 2020-04-13 23:59:57  128.588067     0.701491
# 2020-04-13 23:59:58  127.902731     0.700265
# 2020-04-13 23:59:59  127.481159     0.699875
# 2020-04-14 00:00:00  127.047655     0.700232
#
# [86401 rows x 2 columns]

# %%
select_list = [
    '気化器圧力_PV',
    '蒸留塔還流流量_MV',
    'セパレータ外殻温度_MV',
    'HAcタンクレベル_PV',
    '反応器流入組成（VAc）_PV'
]

df[select_list]
# Out:
#                        気化器圧力_PV  蒸留塔還流流量_MV  セパレータ外殻温度_MV  HAcタンクレベル_PV  \
# 2020-04-13 00:00:00  127.983294    4.984884     36.001230      0.500047
# 2020-04-13 00:00:01  128.262272    4.984884     36.001230      0.499237
# 2020-04-13 00:00:02  127.899077    4.984884     36.701108      0.500482
# 2020-04-13 00:00:03  127.622218    4.984884     37.385460      0.500308
# 2020-04-13 00:00:04  127.577243    4.984884     37.636765      0.499781
# ...                         ...         ...           ...           ...
# 2020-04-13 23:59:56  128.403376    4.976050     35.333826      0.502131
# 2020-04-13 23:59:57  128.588067    4.976050     35.163972      0.502405
# 2020-04-13 23:59:58  127.902731    4.976050     34.945022      0.501658
# 2020-04-13 23:59:59  127.481159    4.976050     35.038490      0.502666
# 2020-04-14 00:00:00  127.047655    4.976050     35.421558      0.501206
#
#                      反応器流入組成（VAc）_PV
# 2020-04-13 00:00:00         0.001370
# ...

# %%
df.loc[:, ['気化器圧力_PV', '気化器液面レベル_PV']]
# Out:
#                        気化器圧力_PV  気化器液面レベル_PV
# 2020-04-13 00:00:00  127.983294     0.700204
# 2020-04-13 00:00:01  128.262272     0.700865
# 2020-04-13 00:00:02  127.899077     0.699740
# 2020-04-13 00:00:03  127.622218     0.699970
# 2020-04-13 00:00:04  127.577243     0.700939
# ...                         ...          ...
# 2020-04-13 23:59:56  128.403376     0.699906
# 2020-04-13 23:59:57  128.588067     0.701491
# 2020-04-13 23:59:58  127.902731     0.700265
# 2020-04-13 23:59:59  127.481159     0.699875
# 2020-04-14 00:00:00  127.047655     0.700232
#
# [86401 rows x 2 columns]

# %%
df.loc[:, select_list]
# Out:
#                        気化器圧力_PV  蒸留塔還流流量_MV  セパレータ外殻温度_MV  HAcタンクレベル_PV  \
# 2020-04-13 00:00:00  127.983294    4.984884     36.001230      0.500047
# 2020-04-13 00:00:01  128.262272    4.984884     36.001230      0.499237
# 2020-04-13 00:00:02  127.899077    4.984884     36.701108      0.500482
# 2020-04-13 00:00:03  127.622218    4.984884     37.385460      0.500308
# 2020-04-13 00:00:04  127.577243    4.984884     37.636765      0.499781
# ...                         ...         ...           ...           ...
# 2020-04-13 23:59:56  128.403376    4.976050     35.333826      0.502131
# 2020-04-13 23:59:57  128.588067    4.976050     35.163972      0.502405
# 2020-04-13 23:59:58  127.902731    4.976050     34.945022      0.501658
# 2020-04-13 23:59:59  127.481159    4.976050     35.038490      0.502666
# 2020-04-14 00:00:00  127.047655    4.976050     35.421558      0.501206
#
#                      反応器流入組成（VAc）_PV
# 2020-04-13 00:00:00         0.001370
# ...

# %%
drop_list = [ 'リサイクルガス組成（C2H6）_SV', '排出ガス流量_MV' ]
df.drop(drop_list, axis=1)
# Out:
#                        気化器圧力_PV    気化器圧力_SV   気化器圧力_MV  気化器液面レベル_PV  \
# 2020-04-13 00:00:00  127.983294  127.883920  18.728267     0.700204
# 2020-04-13 00:00:01  128.262272  127.807691  18.728267     0.700865
# 2020-04-13 00:00:02  127.899077  127.991074  19.079324     0.699740
# 2020-04-13 00:00:03  127.622218  127.990697  18.772228     0.699970
# 2020-04-13 00:00:04  127.577243  127.903788  18.605173     0.700939
# ...                         ...         ...        ...          ...
# 2020-04-13 23:59:56  128.403376  127.807067  18.416376     0.699906
# 2020-04-13 23:59:57  128.588067  127.767796  18.841614     0.701491
# 2020-04-13 23:59:58  127.902731  127.835123  19.183040     0.700265
# 2020-04-13 23:59:59  127.481159  127.788436  19.008170     0.699875
# 2020-04-14 00:00:00  127.047655  127.883040  18.830251     0.700232
#
#                      気化器液面レベル_SV   気化器液面レベル_MV    気化器温度_PV  気化器ヒータ出口温度_PV  \
# 2020-04-13 00:00:00          0.7  21876.987772  120.159558     151.274003
# ...

# %%
df.loc['2020-04-13 15:00:00', :]
# Out:
# 気化器圧力_PV                  128.490001
# 気化器圧力_SV                  128.843235
# 気化器圧力_MV                   18.891324
# 気化器液面レベル_PV                 0.701044
# 気化器液面レベル_SV                 0.700000
#                              ...
# 反応器流入組成（HAc）_PV             0.109680
# セパレータ蒸気排出量_MV (Fixed)      16.102600
# アブソーバスクラブ流量_MV (Fixed)     15.119800
# アブソーバ還流流量_MV (Fixed)        0.746000
# 気化器液体流入量_MV (Fixed)         2.192400
# Name: 2020-04-13 15:00:00, Length: 91, dtype: float64

# %%
df.loc['2020-04-13 00:00:00':'2020-04-13 01:00:00', :]
# Out:
#                        気化器圧力_PV    気化器圧力_SV   気化器圧力_MV  気化器液面レベル_PV  \
# 2020-04-13 00:00:00  127.983294  127.883920  18.728267     0.700204
# 2020-04-13 00:00:01  128.262272  127.807691  18.728267     0.700865
# 2020-04-13 00:00:02  127.899077  127.991074  19.079324     0.699740
# 2020-04-13 00:00:03  127.622218  127.990697  18.772228     0.699970
# 2020-04-13 00:00:04  127.577243  127.903788  18.605173     0.700939
# ...                         ...         ...        ...          ...
# 2020-04-13 00:59:56  127.752403  127.986385  18.921323     0.699813
# 2020-04-13 00:59:57  127.840642  127.956000  18.722140     0.699816
# 2020-04-13 00:59:58  128.033727  128.001287  18.709286     0.700335
# 2020-04-13 00:59:59  127.986335  128.047595  18.699198     0.699339
# 2020-04-13 01:00:00  128.244708  127.971575  18.652475     0.699527
#
#                      気化器液面レベル_SV   気化器液面レベル_MV    気化器温度_PV  気化器ヒータ出口温度_PV  \
# 2020-04-13 00:00:00          0.7  21876.987772  120.159558     151.274003
# ...

# %%
df.loc[:'2020-04-13 01:00:00', :]
# Out:
#                        気化器圧力_PV    気化器圧力_SV   気化器圧力_MV  気化器液面レベル_PV  \
# 2020-04-13 00:00:00  127.983294  127.883920  18.728267     0.700204
# 2020-04-13 00:00:01  128.262272  127.807691  18.728267     0.700865
# 2020-04-13 00:00:02  127.899077  127.991074  19.079324     0.699740
# 2020-04-13 00:00:03  127.622218  127.990697  18.772228     0.699970
# 2020-04-13 00:00:04  127.577243  127.903788  18.605173     0.700939
# ...                         ...         ...        ...          ...
# 2020-04-13 00:59:56  127.752403  127.986385  18.921323     0.699813
# 2020-04-13 00:59:57  127.840642  127.956000  18.722140     0.699816
# 2020-04-13 00:59:58  128.033727  128.001287  18.709286     0.700335
# 2020-04-13 00:59:59  127.986335  128.047595  18.699198     0.699339
# 2020-04-13 01:00:00  128.244708  127.971575  18.652475     0.699527
#
#                      気化器液面レベル_SV   気化器液面レベル_MV    気化器温度_PV  気化器ヒータ出口温度_PV  \
# 2020-04-13 00:00:00          0.7  21876.987772  120.159558     151.274003
# ...

# %%
df.loc['2020-04-13 01:00:00':, :]
# Out:
#                        気化器圧力_PV    気化器圧力_SV   気化器圧力_MV  気化器液面レベル_PV  \
# 2020-04-13 01:00:00  128.244708  127.971575  18.652475     0.699527
# 2020-04-13 01:00:01  128.225510  127.983550  18.862891     0.699696
# 2020-04-13 01:00:02  127.558641  128.024344  18.917001     0.699388
# 2020-04-13 01:00:03  127.556940  127.933492  18.633820     0.699109
# 2020-04-13 01:00:04  127.716824  128.001006  18.591748     0.700066
# ...                         ...         ...        ...          ...
# 2020-04-13 23:59:56  128.403376  127.807067  18.416376     0.699906
# 2020-04-13 23:59:57  128.588067  127.767796  18.841614     0.701491
# 2020-04-13 23:59:58  127.902731  127.835123  19.183040     0.700265
# 2020-04-13 23:59:59  127.481159  127.788436  19.008170     0.699875
# 2020-04-14 00:00:00  127.047655  127.883040  18.830251     0.700232
#
#                      気化器液面レベル_SV   気化器液面レベル_MV    気化器温度_PV  気化器ヒータ出口温度_PV  \
# 2020-04-13 01:00:00          0.7  21845.200637  120.041270     150.685139
# ...

# %%
df[df['気化器温度_PV'] > 121]
# Out:
#                        気化器圧力_PV    気化器圧力_SV   気化器圧力_MV  気化器液面レベル_PV  \
# 2020-04-13 08:39:52  129.177129  127.795385  18.530840     0.697855
# 2020-04-13 08:41:11  128.233538  127.810453  18.551324     0.697505
# 2020-04-13 08:41:16  127.585993  127.861829  18.427354     0.695426
# 2020-04-13 08:43:49  127.899797  127.580371  18.668888     0.695216
# 2020-04-13 17:10:05  128.569985  128.507967  18.956391     0.699882
# 2020-04-13 17:10:09  128.568298  128.556217  18.573133     0.699962
# 2020-04-13 17:10:38  128.359196  128.522035  18.994170     0.699114
# 2020-04-13 17:11:19  128.217080  128.454598  18.191984     0.698601
# 2020-04-13 17:11:22  129.031348  128.514826  19.008552     0.699999
# 2020-04-13 17:11:32  127.727912  128.500449  18.456395     0.699026
# 2020-04-13 17:11:50  128.376283  128.374833  19.122920     0.697980
# 2020-04-13 17:11:53  128.585695  128.393361  18.223111     0.698266
# 2020-04-13 17:11:58  127.871475  128.474181  18.475002     0.699186
# ...

# %%
df[(df['気化器温度_PV'] > 121) & (df['気化器圧力_PV'] < 127.5)]
# Out:
#                        気化器圧力_PV    気化器圧力_SV   気化器圧力_MV  気化器液面レベル_PV  \
# 2020-04-13 17:12:42  126.863801  128.379498  18.625667     0.698007
# 2020-04-13 17:14:06  127.242732  128.146894  18.666183     0.696626
# 2020-04-13 17:16:04  127.177377  127.775176  18.479971     0.695652
#
#                      気化器液面レベル_SV   気化器液面レベル_MV    気化器温度_PV  気化器ヒータ出口温度_PV  \
# 2020-04-13 17:12:42          0.7  20510.318741  121.021913     147.449248
# 2020-04-13 17:14:06          0.7  20400.224050  121.052577     147.503435
# 2020-04-13 17:16:04          0.7  20115.817141  121.104736     147.548921
#
#                      気化器ヒータ出口温度_SV  気化器ヒータ熱量_MV  反応器出口温度_PV  反応器出口温度_SV  \
# 2020-04-13 17:12:42     147.257906  7726.895700  168.110359      169.17
# 2020-04-13 17:14:06     147.257906  7726.440911  168.024989      169.17
# 2020-04-13 17:16:04     147.257906  7722.933856  168.164449      169.17
#
#                      反応器外殻温度_MV  熱交換器入口流量（製品ガス）_PV  熱交換器出口温度（リサイクルガス）_PV  \
# ...

# %%
drop_list =df.columns[df.std() == 0]
drop_list
# Out:
# Index(['気化器液面レベル_SV', '熱交換器出力温度（製品ガス）_SV', 'セパレータ液面レベル_SV', 'セパレータ液体温度_SV',
#        'リサイクルガス圧力_SV', 'アブソーバ液面レベル_SV', 'アブソーバ還流温度_SV', 'アブソーバスクラブ温度_SV',
#        '水溶液レベル_SV', '蒸留塔液面レベル_SV', '蒸留塔第5トレイ温度_SV', 'HAcタンクレベル_SV',
#        'リサイクルガス組成（C2H6）_SV', 'セパレータ蒸気排出量_MV (Fixed)'],
#       dtype='object')

# %%
df_ = df.drop(drop_list, axis=1)
df_
# Out:
#                        気化器圧力_PV    気化器圧力_SV   気化器圧力_MV  気化器液面レベル_PV  \
# 2020-04-13 00:00:00  127.983294  127.883920  18.728267     0.700204
# 2020-04-13 00:00:01  128.262272  127.807691  18.728267     0.700865
# 2020-04-13 00:00:02  127.899077  127.991074  19.079324     0.699740
# 2020-04-13 00:00:03  127.622218  127.990697  18.772228     0.699970
# 2020-04-13 00:00:04  127.577243  127.903788  18.605173     0.700939
# ...                         ...         ...        ...          ...
# 2020-04-13 23:59:56  128.403376  127.807067  18.416376     0.699906
# 2020-04-13 23:59:57  128.588067  127.767796  18.841614     0.701491
# 2020-04-13 23:59:58  127.902731  127.835123  19.183040     0.700265
# 2020-04-13 23:59:59  127.481159  127.788436  19.008170     0.699875
# 2020-04-14 00:00:00  127.047655  127.883040  18.830251     0.700232
#
#                       気化器液面レベル_MV    気化器温度_PV  気化器ヒータ出口温度_PV  気化器ヒータ出口温度_SV  \
# ...
